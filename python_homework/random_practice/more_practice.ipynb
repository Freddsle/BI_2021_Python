# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# %% [markdown]
# # Draw a Sierpinski Carpet

# %%
def carpet_sierpinski():
    '''
    Generate and plot Sierpiński carpet.
    '''
    vertices = [(0.0, 0.0), (0.0, 1.0), (1.0, 1.0), (1.0, 0.0),
                (0.0, 0.5), (0.5, 1.0), (1.0, 0.5), (0.5, 0.0)]
    points = []

    x, y = random.choice(vertices)

    for i in range(1000000):
        vx, vy = random.choice(vertices)      
        x = (2 * vx + x) / 3.0
        y = (2 * vy + y) / 3.0
        points.append((x, y))

    x = [x for (x, y) in points]
    y = [y for (x, y) in points]

    plt.figure(figsize=(10,10))
    plt.plot(x, y, 'b.', markersize=0.2)
    plt.title('Sierpiński carpet')
    plt.show()

# %%
carpet_sierpinski()

# %% [markdown]
# # Изучите артефакты секвенирования любой платформы и создайте функцию для симуляции таких данных
#
#
# Illumina MiSeq - single nucleotide substitutions - 10^-3.\
# Illumina HiSeq2000 - single nucleotide substitutions - 10^-3.
#
# Indel errors occurred at a much lower rate compared to substitutions: Rates of 2.8·10−6 (errors per base).
#
# We find that error rates differ by nucleotide substitution types, ranging from 10−5 for A>C/T>G, C>A/G>T, and C>G/G>C changes to 10−4 for A>G/T>C changes.  - https://genomebiology.biomedcentral.com/articles/10.1186/s13059-019-1659-6
#
# Error rate is highly correlated with the sequencing cycle, rising toward the end of each read (дальше чем 60% длины рида?)
#
# https://academic.oup.com/nargab/article/3/1/lqab019/6193612
